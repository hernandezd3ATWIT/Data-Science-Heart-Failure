# %% [markdown]
# # Early Mortality Risk in Heart-Failure Patients
#
# This data science project analyzes clinical data from heart failure patients to identify key factors associated with early mortality. Using demographic, lifestyle, and lab test variables, we explore how different conditions influence survival rates. The project also builds a predictive model to assist clinicians in quickly assessing patient risk.
#
# ## Research Questions
#
# 1. **Demographic Impact**: How do age and sex affect the probability of a death event?
# 2. **Comorbidities & Lifestyle**: Do diabetes, anaemia, high blood pressure, or smoking significantly increase mortality risk?
# 3. **Lab Biomarkers**: Which clinical measures (e.g., ejection fraction, creatinine) are most predictive of survival?
# 4. **Predictive Modeling**: Can we predict a patient’s death event using features collected at admission?
#
# ## Dataset
# - Source: [Kaggle - Heart Failure Clinical Records Dataset](https://www.kaggle.com/datasets/andrewmvd/heart-failure-clinical-data)
# - 299 patient records
# - 13 clinical and demographic features
#
# ## Tools & Libraries
# - Python (Pandas, Matplotlib, Seaborn, Scikit-learn)
# - Jupyter Notebook

# %%
# Q1: Demographic Impact - Age and Sex vs Death Event

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset (make sure it's in the same folder as your notebook)
df = pd.read_csv("heart_failure_clinical_records_dataset.csv")

# %%
# Plot 1: Age vs Death Event (Larger Boxplot)
plt.figure(figsize=(10, 7))  # Bigger figure
sns.boxplot(data=df, x='DEATH_EVENT', y='age')
plt.title("Age vs Death Event", fontsize=16)
plt.xlabel("Death Event (0 = Survived, 1 = Died)", fontsize=13)
plt.ylabel("Age (years)", fontsize=13)
plt.xticks([0, 1], ['Survived', 'Died'], fontsize=12)
plt.yticks(fontsize=11)
plt.tight_layout()
# plt.savefig("Q1_Age_vs_DeathEvent.png", dpi=300)
plt.show()


# Plot 2: Sex vs Death Event
sex_death_pct = pd.crosstab(df['sex'], df['DEATH_EVENT'], normalize='index') * 100
sex_death_pct.columns = ['Survived', 'Died']
sex_death_pct.index = ['Female', 'Male']

plt.figure(figsize=(10, 7))
ax = sex_death_pct.plot(kind='bar', stacked=True, color=['skyblue', 'salmon'], edgecolor='black', figsize=(10, 7))
plt.title("Sex vs Patient Outcome", fontsize=16)
plt.xlabel("Sex", fontsize=14)
plt.ylabel("Percentage (%)", fontsize=14)
plt.xticks(rotation=0, fontsize=13)
plt.yticks(fontsize=12)

plt.legend(title="Patient Outcome", title_fontsize=12, fontsize=11, loc='upper left', bbox_to_anchor=(1.0, 1.0))

plt.tight_layout()
# plt.savefig("Q1_Sex_vs_DeathEvent.png", dpi=300, bbox_inches='tight')  # Tight layout to include legend
plt.show()

# %%
features = ['anaemia', 'diabetes', 'high_blood_pressure', 'smoking']

for feature in features:

    ctab = pd.crosstab(df[feature], df['DEATH_EVENT'], normalize='index') * 100
    ctab.columns = ['Survived', 'Died']
    ctab.index = ['No', 'Yes']

    # Plot
    ax = ctab.plot(kind='bar', stacked=True, color=['skyblue', 'salmon'],
                   edgecolor='black', figsize=(8, 6))
    ax.set_title(f"{feature.replace('_', ' ').title()} vs Death Event", fontsize=15)
    ax.set_xlabel(f"{feature.replace('_', ' ').title()}", fontsize=13)
    ax.set_ylabel("Percentage (%)", fontsize=13)
    ax.tick_params(axis='x', labelsize=12)
    ax.tick_params(axis='y', labelsize=11)
    ax.legend(title="Patient Outcome", title_fontsize=12)
    plt.xticks(rotation=0)

    fig = ax.get_figure()
    fig.tight_layout()
#     fig.savefig(f"Q2_{feature}_vs_DeathEvent.png", dpi=300, bbox_inches='tight')

    plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(data=df, x='DEATH_EVENT', y='ejection_fraction')
plt.title("Ejection Fraction by Patient Outcome", fontsize=16)
plt.xlabel("Patient Outcome", fontsize=13)
plt.ylabel("Ejection Fraction", fontsize=13)
plt.xticks([0, 1], ['Survived', 'Died'], fontsize=12)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.savefig("Q3_ejection_fraction_vs_DeathEvent.png", dpi=300)
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(data=df, x='DEATH_EVENT', y='serum_creatinine')
plt.title("Serum Creatinine by Patient Outcome", fontsize=16)
plt.xlabel("Patient Outcome", fontsize=13)
plt.ylabel("Serum Creatinine", fontsize=13)
plt.xticks([0, 1], ['Survived', 'Died'], fontsize=12)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.savefig("Q3_serum_creatinine_vs_DeathEvent.png", dpi=300)
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(data=df, x='DEATH_EVENT', y='serum_sodium')
plt.title("Serum Sodium by Patient Outcome", fontsize=16)
plt.xlabel("Patient Outcome", fontsize=13)
plt.ylabel("Serum Sodium", fontsize=13)
plt.xticks([0, 1], ['Survived', 'Died'], fontsize=12)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.savefig("Q3_serum_sodium_vs_DeathEvent.png", dpi=300)
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(data=df, x='DEATH_EVENT', y='platelets')
plt.title("Platelets by Patient Outcome", fontsize=16)
plt.xlabel("Patient Outcome", fontsize=13)
plt.ylabel("Platelets", fontsize=13)
plt.xticks([0, 1], ['Survived', 'Died'], fontsize=12)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.savefig("Q3_platelets_vs_DeathEvent.png", dpi=300)
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(data=df, x='DEATH_EVENT', y='creatinine_phosphokinase')
plt.title("Creatinine Phosphokinase by Patient Outcome", fontsize=16)
plt.xlabel("Patient Outcome", fontsize=13)
plt.ylabel("Creatinine Phosphokinase", fontsize=13)
plt.xticks([0, 1], ['Survived', 'Died'], fontsize=12)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.savefig("Q3_creatinine_phosphokinase_vs_DeathEvent.png", dpi=300)
plt.show()

# %%
# !pip install scikit-learn
# Out:
# ...
#   Using cached scikit_learn-1.6.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (31 kB)
# ...
#   Using cached scipy-1.13.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (60 kB)
# ...
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.6.1-cp39-cp39-macosx_10_9_x86_64.whl (12.1 MB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached scipy-1.13.1-cp39-cp39-macosx_10_9_x86_64.whl (39.4 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn]0m 3/4 [scikit-learn]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Q4: Predictive Modeling - Death Event Classification

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier

# Select Features and Target

X = df.drop(columns=['DEATH_EVENT'])
y = df['DEATH_EVENT']

scaler = StandardScaler()
X_scaled = X.copy()
X_scaled[['age', 'ejection_fraction', 'serum_creatinine', 'serum_sodium', 
          'platelets', 'creatinine_phosphokinase']] = scaler.fit_transform(
    X_scaled[['age', 'ejection_fraction', 'serum_creatinine', 'serum_sodium', 
              'platelets', 'creatinine_phosphokinase']]
)

# Train/Test Split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)


# Logistic Regression

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

print("Logistic Regression Report:")
print(classification_report(y_test, y_pred_lr))
ConfusionMatrixDisplay.from_estimator(lr, X_test, y_test, display_labels=['Survived', 'Died'])
plt.title("Logistic Regression - Confusion Matrix")
plt.tight_layout()
plt.savefig("Logistic_Regression_Confusion_Matrix.png", dpi=300)
plt.show()


# Gradient Boosting Classifier

gb = GradientBoostingClassifier(random_state=42)
gb.fit(X_train, y_train)
y_pred_gb = gb.predict(X_test)

print("Gradient Boosting Report:")
print(classification_report(y_test, y_pred_gb))
ConfusionMatrixDisplay.from_estimator(gb, X_test, y_test, display_labels=['Survived', 'Died'])
plt.title("Gradient Boosting - Confusion Matrix")
plt.tight_layout()
plt.savefig("Gradient_Boosting_Confusion_Matrix.png", dpi=300)
plt.show()


# Feature Importance (Gradient Boosting)

importances = gb.feature_importances_
feature_names = X.columns
sorted_idx = importances.argsort()

plt.figure(figsize=(10, 6))
sns.barplot(x=importances[sorted_idx], y=feature_names[sorted_idx])
plt.title("Feature Importance - Gradient Boosting")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.tight_layout()
plt.savefig("Q4_GradientBoosting_FeatureImportance.png", dpi=300)
plt.show()
# Out:
# Logistic Regression Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.97      0.85        35
#            1       0.93      0.56      0.70        25
#
#     accuracy                           0.80        60
#    macro avg       0.84      0.77      0.77        60
# weighted avg       0.83      0.80      0.79        60
# Gradient Boosting Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.89      0.78        35
#            1       0.75      0.48      0.59        25
#
#     accuracy                           0.72        60
#    macro avg       0.73      0.68      0.69        60
# weighted avg       0.72      0.72      0.70        60
